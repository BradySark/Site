# %% [markdown]
# <a href="https://colab.research.google.com/github/BradySark/Site/blob/main/etl_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demonstration of ETL procedure. I will use Amazon data "scraped"/**Extracted** using the BeautifulSoup4 library, **Transfer** it into a dataframe using the Pandaslibrary and save it as a csv file. Finally, I will create a SQLite3 database and **Load** the extracted data into it.
#
# STEP 1: Loading required libraries

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3

# %% [markdown]
# STEP 2: Python code to **Extract** Web Data from Amazon. Top 30 Best Selling Books

# %%
# Scraping data from web page for Amazon-Best Sellers
url = 'https://www.amazon.com/gp/bestsellers/books/11892'
request = Request(url, headers={'User-agent': 'Mozilla/5.0'})
html = urlopen(request)

soup = BeautifulSoup(html, 'html.parser')

books = soup.find_all('div', id="gridItemRoot")
#print(books)
bookdata=[]

for book in books:
    rank = book.find('span', class_="zg-bdg-text").get_text().replace('#', '')
    #print(rank)
    title = book.find('div', class_="_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y").get_text(strip=True)
    #print(f"Title: {title}")
    author = book.find('div', class_="a-row a-size-small").get_text(strip=True)
    #print(f"Author: {author}")
    bookdata.append([rank, title, author])

#print(bookdata)
booksdf = pd.DataFrame(bookdata, columns = ['Ranking', 'Title', 'Author'])
booksdf
# Out:
#    Ranking                                              Title  \
# 0        1                  On Writing: A Memoir of the Craft
# 1        2                                      Julia Cameron
# 2        3  The Emotion Thesaurus: A Writer's Guide to Cha...
# 3        4  Writing Down the Bones: Freeing the Writer Within
# 4        5                                  A Poetry Handbook
# 5        6  Maps and Legends: Reading and Writing Along th...
# 6        7  The Only World Building Workbook You'll Ever N...
# 7        8  The Art and Business of Online Writing: How to...
# 8        9  The Secrets to Creating Character Arcs: A Fict...
# 9       10  The Emotional Wound Thesaurus: A Writer's Guid...
# 10      11  Writer´s Workbook: A Personal Planner with Tip...
# 11      12  The Conflict Thesaurus: A Writer's Guide to Ob...
# 12      13  How To Self-Publish A Children's Book: Everyth...
# 13      14                                       Jenna Moreci
# 14      15  Refuse to Be Done: How to Write and Rewrite a ...
# 15      16  Digital Zettelkasten: Principles, Methods, & E...
# 16      17  Write Useful Books: A modern approach to desig...
# 17      18  Writing Picture Books Revised and Expanded Edi...
# 18      19  The Secrets to Creating Character Arcs: A Fict...
# 19      20  Romancing the Beat: Story Structure for Romanc...
# 20      21  5,000 WRITING PROMPTS: A Master List of Plot I...
# 21      22  The Writer's Toolbox: Creative Games and Exerc...
# 22      23                                The Trope Thesaurus
# 23      24  The Negative Trait Thesaurus: A Writer's Guide...
# 24      25  Write Useful Books: A modern approach to desig...
# 25      26  The Emotional Craft of Fiction: How to Write t...
# 26      27  The Only Fantasy Workbook You'll Ever Need: Yo...
# 27      28  Consider This: Moments in My Writing Life Afte...
# 28      29  Nobody Wants to Read Your Sh*t: And Other Toug...
# 29      30  Story Genius: How to Use Brain Science to Go B...
#
#                Author
# 0        Stephen King
# 1       Julia Cameron
# 2       Becca Puglisi
# 3    Natalie Goldberg
# 4         Mary Oliver
# 5      Michael Chabon
# 6       T.M. Holladay
# 7        Nicolas Cole
# 8      John S. Warner
# 9       Becca Puglisi
# 10       Tanja Hanika
# 11      Becca Puglisi
# 12       Yvonne Jones
# 13       Jenna Moreci
# 14          Matt Bell
# 15       David Kadavy
# 16    Rob Fitzpatrick
# 17  Ann Whitford Paul
# 18     John S. Warner
# 19         Gwen Hayes
# 20       Bryn Donovan
# 21   Jamie Cat Callan
# 22      Jennifer Hilt
# 23    Angela Ackerman
# 24    Rob Fitzpatrick
# 25       Donald Maass
# 26      T.M. Holladay
# 27    Chuck Palahniuk
# 28  Steven Pressfield
# 29          Lisa Cron

# %% [markdown]
# STEP 3: Found an issue. Two authors names, Julia Cameron and Jenna Moreci, ended up in their "Titles". Using Pandas to clean the data.

# %%
booksdf['Title'] = booksdf['Title'].replace(['Julia Cameron'], 'Write For Life')
booksdf['Title'] = booksdf['Title'].replace(['Jenna Moreci'], 'Shut Up and Write the Book')
booksdf
# Out:
#    Ranking                                              Title  \
# 0        1                  On Writing: A Memoir of the Craft
# 1        2                                     Write For Life
# 2        3  The Emotion Thesaurus: A Writer's Guide to Cha...
# 3        4  Writing Down the Bones: Freeing the Writer Within
# 4        5                                  A Poetry Handbook
# 5        6  Maps and Legends: Reading and Writing Along th...
# 6        7  The Only World Building Workbook You'll Ever N...
# 7        8  The Art and Business of Online Writing: How to...
# 8        9  The Secrets to Creating Character Arcs: A Fict...
# 9       10  The Emotional Wound Thesaurus: A Writer's Guid...
# 10      11  Writer´s Workbook: A Personal Planner with Tip...
# 11      12  The Conflict Thesaurus: A Writer's Guide to Ob...
# 12      13  How To Self-Publish A Children's Book: Everyth...
# 13      14                         Shut Up and Write the Book
# 14      15  Refuse to Be Done: How to Write and Rewrite a ...
# 15      16  Digital Zettelkasten: Principles, Methods, & E...
# 16      17  Write Useful Books: A modern approach to desig...
# 17      18  Writing Picture Books Revised and Expanded Edi...
# 18      19  The Secrets to Creating Character Arcs: A Fict...
# 19      20  Romancing the Beat: Story Structure for Romanc...
# 20      21  5,000 WRITING PROMPTS: A Master List of Plot I...
# 21      22  The Writer's Toolbox: Creative Games and Exerc...
# 22      23                                The Trope Thesaurus
# 23      24  The Negative Trait Thesaurus: A Writer's Guide...
# 24      25  Write Useful Books: A modern approach to desig...
# 25      26  The Emotional Craft of Fiction: How to Write t...
# 26      27  The Only Fantasy Workbook You'll Ever Need: Yo...
# 27      28  Consider This: Moments in My Writing Life Afte...
# 28      29  Nobody Wants to Read Your Sh*t: And Other Toug...
# 29      30  Story Genius: How to Use Brain Science to Go B...
#
#                Author
# 0        Stephen King
# 1       Julia Cameron
# 2       Becca Puglisi
# 3    Natalie Goldberg
# 4         Mary Oliver
# 5      Michael Chabon
# 6       T.M. Holladay
# 7        Nicolas Cole
# 8      John S. Warner
# 9       Becca Puglisi
# 10       Tanja Hanika
# 11      Becca Puglisi
# 12       Yvonne Jones
# 13       Jenna Moreci
# 14          Matt Bell
# 15       David Kadavy
# 16    Rob Fitzpatrick
# 17  Ann Whitford Paul
# 18     John S. Warner
# 19         Gwen Hayes
# 20       Bryn Donovan
# 21   Jamie Cat Callan
# 22      Jennifer Hilt
# 23    Angela Ackerman
# 24    Rob Fitzpatrick
# 25       Donald Maass
# 26      T.M. Holladay
# 27    Chuck Palahniuk
# 28  Steven Pressfield
# 29          Lisa Cron

# %% [markdown]
# STEP 4: With the data "cleaned", it is ready to be saved as a csv file.

# %%
booksdf.to_csv('best_sellerCLEAN.csv', index=False)
cleandf = pd.read_csv('best_sellerCLEAN.csv')
cleandf
# Out:
#     Ranking                                              Title  \
# 0         1                  On Writing: A Memoir of the Craft
# 1         2                                     Write For Life
# 2         3  The Emotion Thesaurus: A Writer's Guide to Cha...
# 3         4  Writing Down the Bones: Freeing the Writer Within
# 4         5                                  A Poetry Handbook
# 5         6  Maps and Legends: Reading and Writing Along th...
# 6         7  The Only World Building Workbook You'll Ever N...
# 7         8  The Art and Business of Online Writing: How to...
# 8         9  The Secrets to Creating Character Arcs: A Fict...
# 9        10  The Emotional Wound Thesaurus: A Writer's Guid...
# 10       11  Writer´s Workbook: A Personal Planner with Tip...
# 11       12  The Conflict Thesaurus: A Writer's Guide to Ob...
# 12       13  How To Self-Publish A Children's Book: Everyth...
# 13       14                         Shut Up and Write the Book
# 14       15  Refuse to Be Done: How to Write and Rewrite a ...
# 15       16  Digital Zettelkasten: Principles, Methods, & E...
# 16       17  Write Useful Books: A modern approach to desig...
# 17       18  Writing Picture Books Revised and Expanded Edi...
# 18       19  The Secrets to Creating Character Arcs: A Fict...
# 19       20  Romancing the Beat: Story Structure for Romanc...
# 20       21  5,000 WRITING PROMPTS: A Master List of Plot I...
# 21       22  The Writer's Toolbox: Creative Games and Exerc...
# 22       23                                The Trope Thesaurus
# 23       24  The Negative Trait Thesaurus: A Writer's Guide...
# 24       25  Write Useful Books: A modern approach to desig...
# 25       26  The Emotional Craft of Fiction: How to Write t...
# 26       27  The Only Fantasy Workbook You'll Ever Need: Yo...
# 27       28  Consider This: Moments in My Writing Life Afte...
# 28       29  Nobody Wants to Read Your Sh*t: And Other Toug...
# 29       30  Story Genius: How to Use Brain Science to Go B...
#
#                Author
# 0        Stephen King
# 1       Julia Cameron
# 2       Becca Puglisi
# 3    Natalie Goldberg
# 4         Mary Oliver
# 5      Michael Chabon
# 6       T.M. Holladay
# 7        Nicolas Cole
# 8      John S. Warner
# 9       Becca Puglisi
# 10       Tanja Hanika
# 11      Becca Puglisi
# 12       Yvonne Jones
# 13       Jenna Moreci
# 14          Matt Bell
# 15       David Kadavy
# 16    Rob Fitzpatrick
# 17  Ann Whitford Paul
# 18     John S. Warner
# 19         Gwen Hayes
# 20       Bryn Donovan
# 21   Jamie Cat Callan
# 22      Jennifer Hilt
# 23    Angela Ackerman
# 24    Rob Fitzpatrick
# 25       Donald Maass
# 26      T.M. Holladay
# 27    Chuck Palahniuk
# 28  Steven Pressfield
# 29          Lisa Cron

# %% [markdown]
# Ready to build a SQLite3 database, and load the data. I checked to make sure it loaded correctly and is able to be queried and manipulated as needed.

# %%
conn = sqlite3.connect('best_seller.db')
cur = conn.cursor()
cur.execute('DROP TABLE IF EXISTS Books')
cur.execute('''CREATE TABLE Books (Ranking int, Title text, Author text)''')

BSBooks = pd.read_csv('best_sellerCLEAN.csv')
BSBooks.to_sql('Books', conn, if_exists='append', index = False)

 
data=cur.execute('''SELECT * FROM Books''')
for row in data:
    print(row)

print('Voila!') 

conn.close()
# Out:
# (1, 'On Writing: A Memoir of the Craft', 'Stephen King')
# (2, 'Write For Life', 'Julia Cameron')
# (3, "The Emotion Thesaurus: A Writer's Guide to Character Expression (Second Edition) (Writers Helping Writers Series)", 'Becca Puglisi')
# (4, 'Writing Down the Bones: Freeing the Writer Within', 'Natalie Goldberg')
# (5, 'A Poetry Handbook', 'Mary Oliver')
# (6, 'Maps and Legends: Reading and Writing Along the Borderlands', 'Michael Chabon')
# (7, "The Only World Building Workbook You'll Ever Need: Your New Setting Bible (Series Bibles for Writers)", 'T.M. Holladay')
# (8, 'The Art and Business of Online Writing: How to Beat the Game of Capturing and Keeping Attention', 'Nicolas Cole')
# (9, "The Secrets to Creating Character Arcs: A Fiction Writer's Guide to Masterful Character Creation", 'John S. Warner')
# (10, "The Emotional Wound Thesaurus: A Writer's Guide to Psychological Trauma (Writers Helping Writers Series)", 'Becca Puglisi')
# (11, 'Writer´s Workbook: A Personal Planner with Tips, Checklists and Guidelines', 'Tanja Hanika')
# (12, "The Conflict Thesaurus: A Writer's Guide to Obstacles, Adversaries, and Inner Struggles (Volume 2) (Writers Helping Writers Series)", 'Becca Puglisi')
# (13, "How To Self-Publish A Children's Book: Everything You Need To Know To Write, Illustrate, Publish, And Market Your Paperback And Ebook (How To Write For Children Series)", 'Yvonne Jones')
# (14, 'Shut Up and Write the Book', 'Jenna Moreci')
# (15, 'Refuse to Be Done: How to Write and Rewrite a Novel in Three Drafts', 'Matt Bell')
# (16, 'Digital Zettelkasten: Principles, Methods, & Examples', 'David Kadavy')
# (17, 'Write Useful Books: A modern approach to designing and refining recommendable nonfiction', 'Rob Fitzpatrick')
# (18, 'Writing Picture Books Revised and Expanded Edition: A Hands-On Guide From Story Creation to Publication', 'Ann Whitford Paul')
# (19, "The Secrets to Creating Character Arcs: A Fiction Writer's Guide to Masterful Character Creation", 'John S. Warner')
# (20, 'Romancing the Beat: Story Structure for Romance Novels (How to Write Kissing Books Book 1)', 'Gwen Hayes')
# (21, '5,000 WRITING PROMPTS: A Master List of Plot Ideas, Creative Exercises, and More', 'Bryn Donovan')
# (22, "The Writer's Toolbox: Creative Games and Exercises for Inspiring the 'Write' Side of Your Brain (Writing Prompts, Writer Gifts, Writing Kit Gifts)", 'Jamie Cat Callan')
# (23, 'The Trope Thesaurus', 'Jennifer Hilt')
# (24, "The Negative Trait Thesaurus: A Writer's Guide to Character Flaws (Writers Helping Writers Series)", 'Angela Ackerman')
# (25, 'Write Useful Books: A modern approach to designing and refining recommendable nonfiction', 'Rob Fitzpatrick')
# (26, 'The Emotional Craft of Fiction: How to Write the Story Beneath the Surface', 'Donald Maass')
# (27, "The Only Fantasy Workbook You'll Ever Need: Your New Magic System Bible (Series Bibles for Writers)", 'T.M. Holladay')
# (28, 'Consider This: Moments in My Writing Life After Which Everything Was Different', 'Chuck Palahniuk')
# (29, 'Nobody Wants to Read Your Sh*t: And Other Tough-Love Truths to Make You a Better Writer', 'Steven Pressfield')
# (30, 'Story Genius: How to Use Brain Science to Go Beyond Outlining and Write a Riveting Novel (Before You Waste Three Years Writing 327 Pages That Go Nowhere)', 'Lisa Cron')
# Voila!
